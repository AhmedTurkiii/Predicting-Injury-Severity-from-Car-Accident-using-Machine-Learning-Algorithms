# %% [markdown]
# # **Predicting if Car Accidents Result in Injuries in Maryland**
# Dalia Cabrera, Ahmed Torki, Sergio Zavala
#
# *May 1, 2025*

# %% [markdown]
# ## Introduction

# %% [markdown]
# Using crash-related factors like weather, vehicle damage, and and surface condition, can we predict the likelihood of driver injury? In this project, we explore that question by building two machine learning models using data from the Maryland Open Crash Reporting System.
#
# Our primary goal is to classify injury severity based on pre-crash and crash-related conditions. Along the way, we also aim to explore broader questions:
#
# - What circumstances are most strongly associated with injury during a crash?
#
# - Can such models help inform safer driving habits under risky conditions?
#
# - In early moments after a crash (before official reports), could predictive tools help families understand the likelihood of injury?
#
# Source: https://data.montgomerycountymd.gov/Public-Safety/Crash-Reporting-Drivers-Data/mmzv-x632/about_data

# %% [markdown]
# ## Read the data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.feature_selection import SelectKBest, mutual_info_classif
import warnings
from sklearn.exceptions import ConvergenceWarning
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, export_graphviz, plot_tree
import graphviz
from sklearn.ensemble import IsolationForest
from sklearn.exceptions import ConvergenceWarning

warnings.filterwarnings('ignore', category=ConvergenceWarning)

# %%
url = 'https://drive.google.com/file/d/1_ej7isccNUR2JAtaHQrRgqGFucWWP_gK/view?usp=share_link'
file_id = url.split('/')[-2]
read_url = f'https://drive.google.com/uc?id={file_id}'
df = pd.read_csv(read_url)
# Out:
# /var/folders/7s/y2ptxpt11h7fpjjqb4cphgcc0000gn/T/ipykernel_72480/731982752.py:4: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(read_url)

# %% [markdown]
# ## Initial exploration

# %% [markdown]
# To get a feel for the data, we ran `.head()`, `.shape`, `.columns`, `.info()`, and `.describe()`.

# %% [markdown]
# #### `.head()` gives us a quick peek at the first few rows.

# %%
df.head()
# Out:
#   Report Number Local Case Number                Agency Name  \
# 0    DM8479000T         210020119  Takoma Park Police Depart
# 1   MCP2970000R          15045937                 MONTGOMERY
# 2   MCP20160036         180040948   Montgomery County Police
# 3    EJ7879003C         230048975  Gaithersburg Police Depar
# 4   MCP2967004Y         230070277   Montgomery County Police
#
#         ACRS Report Type         Crash Date/Time        Route Type  \
# 0  Property Damage Crash  05/27/2021 07:40:00 PM               NaN
# 1  Property Damage Crash  09/11/2015 01:29:00 PM               NaN
# 2  Property Damage Crash  08/17/2018 02:25:00 PM               NaN
# 3           Injury Crash  08/11/2023 06:00:00 PM               NaN
# 4  Property Damage Crash  12/06/2023 06:42:00 PM  Maryland (State)
#
#          Road Name Cross-Street Name               Off-Road Description  \
# 0              NaN               NaN                     IN PARKING LOT
# 1              NaN               NaN    Parking Lot: \n2525 Ennalls Ave
# 2              NaN               NaN  PARKING LOT OF 16246 FREDERICK RD
# 3              NaN               NaN                   1 N SUMMIT DRIVE
# 4  CONNECTICUT AVE      BALTIMORE ST                                NaN
#
#   Municipality  ... Vehicle Going Dir Speed Limit Driverless Vehicle  \
# 0          NaN  ...               NaN           0                 No
# 1          NaN  ...             South           5                 No
# 2          NaN  ...              West          15                 No
# 3          NaN  ...           Unknown          15                 No
# 4   KENSINGTON  ...             South          35                 No
#
#   Parked Vehicle Vehicle Year Vehicle Make Vehicle Model   Latitude  \
# 0            Yes         2017         HINO           TWK  38.987657
# 1             No         2012       TOYOTA            SU  39.039917
# 2             No         2015         MAZD            TK  38.743373
# 3             No         2018          RAM            TK  39.145873
# 4             No         2017         AUDI            A3  39.025170
#
#    Longitude                     Location
# 0 -76.987545    (38.98765667, -76.987545)
# 1 -77.053649  (39.03991652, -77.05364898)
# 2 -77.546997    (38.743373, -77.54699707)
# 3 -77.191940  (39.14587303, -77.19194047)
# 4 -77.076333  (39.02517017, -77.07633333)
#
# [5 rows x 39 columns]

# %% [markdown]
# #### `.shape` tells us how big the dataset is.

# %%
df.shape
# Out:
# (195692, 39)

# %% [markdown]
# #### `.columns` lets us scroll through all the column names to see what we're working with.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195692 entries, 0 to 195691
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Report Number                  195692 non-null  object
#  1   Local Case Number              195692 non-null  object
#  2   Agency Name                    195692 non-null  object
#  3   ACRS Report Type               195692 non-null  object
#  4   Crash Date/Time                195692 non-null  object
#  5   Route Type                     176568 non-null  object
#  6   Road Name                      174569 non-null  object
#  7   Cross-Street Name              164921 non-null  object
#  8   Off-Road Description           18086 non-null   object
#  9   Municipality                   19126 non-null   object
#  10  Related Non-Motorist           6310 non-null    object
#  11  Collision Type                 195107 non-null  object
#  12  Weather                        182336 non-null  object
#  13  Surface Condition              173324 non-null  object
#  14  Light                          194247 non-null  object
#  15  Traffic Control                168115 non-null  object
#  16  Driver Substance Abuse         164372 non-null  object
#  17  Non-Motorist Substance Abuse   5164 non-null    object
#  18  Person ID                      195692 non-null  object
#  19  Driver At Fault                195692 non-null  object
#  20  Injury Severity                194194 non-null  object
#  21  Circumstance                   37326 non-null   object
#  22  Driver Distracted By           194074 non-null  object
#  23  Drivers License State          183085 non-null  object
#  24  Vehicle ID                     195692 non-null  object
#  25  Vehicle Damage Extent          195376 non-null  object
#  26  Vehicle First Impact Location  195536 non-null  object
#  27  Vehicle Body Type              192759 non-null  object
#  28  Vehicle Movement               194535 non-null  object
#  29  Vehicle Going Dir              188914 non-null  object
#  30  Speed Limit                    195692 non-null  int64
#  31  Driverless Vehicle             195692 non-null  object
#  32  Parked Vehicle                 194165 non-null  object
#  33  Vehicle Year                   195692 non-null  int64
#  34  Vehicle Make                   195026 non-null  object
#  35  Vehicle Model                  194984 non-null  object
#  36  Latitude                       195692 non-null  float64
#  37  Longitude                      195692 non-null  float64
#  38  Location                       195692 non-null  object
# dtypes: float64(2), int64(2), object(35)
# memory usage: 58.2+ MB

# %% [markdown]
# #### `.info()` showed us the data types and how much missing data there might be.

# %%
df.describe()
# Out:
#          Speed Limit   Vehicle Year       Latitude      Longitude
# count  195692.000000  195692.000000  195692.000000  195692.000000
# mean       32.298229    1965.631855      39.083074     -77.112138
# std        11.237255     340.581440       0.071862       0.098248
# min         0.000000       0.000000      37.720000     -79.486000
# 25%        25.000000    2006.000000      39.024425     -77.189364
# 50%        35.000000    2012.000000      39.074865     -77.105216
# 75%        40.000000    2016.000000      39.139840     -77.039155
# max        75.000000    9999.000000      39.990414     -75.527708

# %% [markdown]
# #### `.describe()` gave us some basic stats for the numeric columns.

# %%
df.columns
# Out:
# Index(['Report Number', 'Local Case Number', 'Agency Name', 'ACRS Report Type',
#        'Crash Date/Time', 'Route Type', 'Road Name', 'Cross-Street Name',
#        'Off-Road Description', 'Municipality', 'Related Non-Motorist',
#        'Collision Type', 'Weather', 'Surface Condition', 'Light',
#        'Traffic Control', 'Driver Substance Abuse',
#        'Non-Motorist Substance Abuse', 'Person ID', 'Driver At Fault',
#        'Injury Severity', 'Circumstance', 'Driver Distracted By',
#        'Drivers License State', 'Vehicle ID', 'Vehicle Damage Extent',
#        'Vehicle First Impact Location', 'Vehicle Body Type',
#        'Vehicle Movement', 'Vehicle Going Dir', 'Speed Limit',
#        'Driverless Vehicle', 'Parked Vehicle', 'Vehicle Year', 'Vehicle Make',
#        'Vehicle Model', 'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %% [markdown]
# ## Exploration and visualization

# %% [markdown]
# ### Missing Data Check
# We looked at how much data is missing in each column. Some features like Non-Motorist Substance Abuse, Municipality, and Circumstance are missing in over 80% of the rows, so we'll probably drop those or handle them carefully if we decide to keep them. The good news is that most of our key predictors and the target variable (Injury Severity) are mostly complete.

# %%
missing_values = df.isna().mean().sort_values(ascending=False)
missing_values[missing_values > 0.1].plot(kind='barh', figsize=(10,6), title='Columns with >10% Missing Data')
plt.xlabel('Fraction Missing')
plt.show();

# %% [markdown]
# ### Injury Severity Distribution
# We looked at how often each injury severity level appears. This showed us that the dataset is highly imbalanced when it comes to the variable target severity.

# %%
df['Injury Severity'].value_counts().plot(kind='bar', title='Injury Severity Counts')
plt.xlabel('Injury Severity')
plt.ylabel('Count')
plt.show();

# %% [markdown]
# ### Visualizing Predictor Variables
# We explored our predictor variables to see how their values are distributed. Helping us get a better sense of the data and spot anything weird or imbalanced.

# %%
df['Collision Type'].value_counts().plot(kind='bar', title='Collision Type Distribution')
plt.xlabel('Collision Type')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show();

# %%
df['Vehicle Damage Extent'].value_counts().plot(kind='bar', title='Vehicle Damage Extent Distribution')
plt.xlabel('Damage Extent')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show();

# %%
df['Weather'].value_counts().plot(kind='bar', title='Weather Conditions During Crash')
plt.xlabel('Weather')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show();

# %%
plt.figure(figsize=(12,6))
df['Driver Substance Abuse'].value_counts().plot(kind='bar')
plt.title('Driver Substance Abuse', fontsize=14)
plt.xlabel('Substance Abuse', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show();

# %%
df['Surface Condition'].value_counts().plot(kind='bar', title='Surface Condition Distribution')
plt.xlabel('Surface Condition')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show();

# %%
df['Light'].value_counts().plot(kind='bar', title='Lighting Conditions During Crash')
plt.xlabel('Light Condition')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show();

# %% [markdown]
# We checked if there's a pattern between average speed limits and injury severity. Fatal injuries happened at slightly higher speed limits but the differences aren’t too significant.

# %%
df.groupby('Injury Severity')['Speed Limit'].mean().plot(kind='bar')
plt.ylabel('Average Speed Limit')
plt.title('Average Speed Limit by Injury Severity')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show();

# %% [markdown]
# ## Initial preprocessing and cleaning
#
# - Treat missing and bad data
# - Remove useless or irrelevant columns
# - Remove any  output related columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195692 entries, 0 to 195691
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Report Number                  195692 non-null  object
#  1   Local Case Number              195692 non-null  object
#  2   Agency Name                    195692 non-null  object
#  3   ACRS Report Type               195692 non-null  object
#  4   Crash Date/Time                195692 non-null  object
#  5   Route Type                     176568 non-null  object
#  6   Road Name                      174569 non-null  object
#  7   Cross-Street Name              164921 non-null  object
#  8   Off-Road Description           18086 non-null   object
#  9   Municipality                   19126 non-null   object
#  10  Related Non-Motorist           6310 non-null    object
#  11  Collision Type                 195107 non-null  object
#  12  Weather                        182336 non-null  object
#  13  Surface Condition              173324 non-null  object
#  14  Light                          194247 non-null  object
#  15  Traffic Control                168115 non-null  object
#  16  Driver Substance Abuse         164372 non-null  object
#  17  Non-Motorist Substance Abuse   5164 non-null    object
#  18  Person ID                      195692 non-null  object
#  19  Driver At Fault                195692 non-null  object
#  20  Injury Severity                194194 non-null  object
#  21  Circumstance                   37326 non-null   object
#  22  Driver Distracted By           194074 non-null  object
#  23  Drivers License State          183085 non-null  object
#  24  Vehicle ID                     195692 non-null  object
#  25  Vehicle Damage Extent          195376 non-null  object
#  26  Vehicle First Impact Location  195536 non-null  object
#  27  Vehicle Body Type              192759 non-null  object
#  28  Vehicle Movement               194535 non-null  object
#  29  Vehicle Going Dir              188914 non-null  object
#  30  Speed Limit                    195692 non-null  int64
#  31  Driverless Vehicle             195692 non-null  object
#  32  Parked Vehicle                 194165 non-null  object
#  33  Vehicle Year                   195692 non-null  int64
#  34  Vehicle Make                   195026 non-null  object
#  35  Vehicle Model                  194984 non-null  object
#  36  Latitude                       195692 non-null  float64
#  37  Longitude                      195692 non-null  float64
#  38  Location                       195692 non-null  object
# dtypes: float64(2), int64(2), object(35)
# memory usage: 58.2+ MB

# %% [markdown]
# **Irrelevant Columns**:
#
# (*We are focusing on features that could potentially have an impact severity level of a crash*)
#
# - ID numbers (Report Number, Local Case Number, etc)
# - ACRS Report Type, Off-Road Description, Drivers License State (Dataset focuses mainly on Maryland), Route Type (Not many unique routes since the focus is Maryland)
# - Too many NAs: Municipality, Related Non-Motorist, Non-Motorist Substance Abuse, Circumstance
# - Driverless vehicle values are No or Unknown, since there are only a few rows of Unknown, we can just remove those rows
# - Location / Lat / Long are not really predictive
# - We can just grab hour and weekday from Date/Time

# %%
# Convert Date to pandas
df['Crash Date/Time'] = pd.to_datetime(df['Crash Date/Time'])
df['Crash Hour'] = df['Crash Date/Time'].dt.hour
df['Crash Weekday'] = df['Crash Date/Time'].dt.weekday

# IDs/Names
df.drop(['Report Number', 'Local Case Number', 'Agency Name', 'Road Name', 'Cross-Street Name', 'Person ID', 'Vehicle ID'], axis=1, inplace=True)
# Descriptions
df.drop(['ACRS Report Type', 'Off-Road Description', 'Drivers License State', 'Route Type'], axis=1, inplace=True)
# Too Many NAs or unbalanced
df.drop(['Municipality', 'Related Non-Motorist', 'Non-Motorist Substance Abuse', 'Circumstance', 'Driverless Vehicle'], axis=1, inplace=True)
# Drop Lat, Long, and Loc, Date, or Useless
df.drop(['Latitude', 'Longitude', 'Location', 'Crash Date/Time', 'Vehicle Going Dir', 'Parked Vehicle'], axis=1, inplace=True)

df.info()
# Out:
# /var/folders/7s/y2ptxpt11h7fpjjqb4cphgcc0000gn/T/ipykernel_72480/1679391936.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Crash Date/Time'] = pd.to_datetime(df['Crash Date/Time'])
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195692 entries, 0 to 195691
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Collision Type                 195107 non-null  object
#  1   Weather                        182336 non-null  object
#  2   Surface Condition              173324 non-null  object
#  3   Light                          194247 non-null  object
#  4   Traffic Control                168115 non-null  object
#  5   Driver Substance Abuse         164372 non-null  object
#  6   Driver At Fault                195692 non-null  object
#  7   Injury Severity                194194 non-null  object
#  8   Driver Distracted By           194074 non-null  object
#  9   Vehicle Damage Extent          195376 non-null  object
#  10  Vehicle First Impact Location  195536 non-null  object
#  11  Vehicle Body Type              192759 non-null  object
#  12  Vehicle Movement               194535 non-null  object
#  13  Speed Limit                    195692 non-null  int64
#  14  Vehicle Year                   195692 non-null  int64
#  15  Vehicle Make                   195026 non-null  object
#  16  Vehicle Model                  194984 non-null  object
#  17  Crash Hour                     195692 non-null  int32
#  18  Crash Weekday                  195692 non-null  int32
# dtypes: int32(2), int64(2), object(15)
# memory usage: 26.9+ MB

# %% [markdown]
# Before we look more into the predictors, lets see how the data looks inside out target value.

# %%
df['Injury Severity'].value_counts()
# Out:
# Injury Severity
# NO APPARENT INJURY          141196
# No Apparent Injury           18301
# POSSIBLE INJURY              17481
# SUSPECTED MINOR INJURY       11871
# Suspected Minor Injury        1998
# Possible Injury               1566
# SUSPECTED SERIOUS INJURY      1414
# Suspected Serious Injury       188
# FATAL INJURY                   154
# Fatal Injury                    25
# Name: count, dtype: int64

# %% [markdown]
# The categories seem to range between no injury, minor injury, serious injury and fatal injury. Since there are alot of "possible injuries", we can't just remove them, so our safest bet would be to just sepearte no injury and injuries into two distinct categories! We can also encode our column values using ordinal encoding. Since there are so many injuries, we should just focus on balancing them out!

# %%
df['Injury'] = df['Injury Severity'].str.upper()
df.loc[df['Injury'] != 'NO APPARENT INJURY', 'Injury'] = 'INJURY'
df['Injury'] = df['Injury'].replace({
    'NO APPARENT INJURY': 'NO INJURY'
})
severity_map = {
    'NO INJURY': 0,
    'INJURY': 1
}
df['Injury'] = df['Injury'].map(severity_map)
df.drop('Injury Severity', axis=1, inplace=True)

# %%
min_class_count = df['Injury'].value_counts().min()

df_balanced = (
    df.groupby('Injury', group_keys=False)
      .apply(lambda x: x.sample(min_class_count, random_state=42))
      .sample(frac=1, random_state=42)  # Optional: shuffle
      .reset_index(drop=True)
)

print(df_balanced['Injury'].value_counts())
df = df_balanced;
# Out:
# Injury
# 1    36195
# 0    36195
# Name: count, dtype: int64
# /var/folders/7s/y2ptxpt11h7fpjjqb4cphgcc0000gn/T/ipykernel_72480/842896628.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(min_class_count, random_state=42))

# %% [markdown]
# Now lets work on cleaning up our predictor values:
# - Collision type has several unique values, so just focusing on the most seen
# - Weather has many unique values, but too many unknown, so just grabbing top 5
# - The top 4 Surface Condition take up almost every row, so we can just set the rare occasions to OTHER.
# - Light just needs a few values combined.
# - Traffic control has a lot more unique values, grabbing top 3, rest as other
# - Driver at fault is good as it is
# - Top 2 substance abuse categories simplified
# - Simplified Driver Distracted By and kept Other and Unknown as sepearate values since we have too many unknown values to just remove them, but other does not mean unknown since it could mean some type of distraction, so I kept them seperate.
# - Grabbed the top 3 most seen damage types.
# - The times had many similar values but different formatting (extra spacing, different caps), so by normalizing to data with uppercase and removing spaces, we combined many values and grabbed the top 6.
# - Simplified a few car body types and grabbed top 5
# - Grabbed the top 5 vehicle movements based on value count
# - Simplified and grabbed the most seen car makes and models.
# - There are a few car years that go over 2025 and lower than 1980, so it is probably best to drop those.

# %%
# Top 5 collision types
top_collision_types = df['Collision Type'].str.upper().value_counts().index[:6]
df['Collision Type'] = df['Collision Type'].apply(
    lambda x: str(x).upper() if str(x).upper() in top_collision_types else 'OTHER'
)

# Top 4 weather conditions
top_weather = df['Weather'].str.upper().value_counts().index[:5]
df['Weather'] = df['Weather'].apply(
    lambda x: str(x).upper() if str(x).upper() in top_weather else 'OTHER'
)
df['Weather'] = df['Weather'].replace({
    'RAINING': 'RAIN'
})

# Top 3 surface conditions
top_surface = df['Surface Condition'].str.upper().value_counts().index[:4]
df['Surface Condition'] = df['Surface Condition'].apply(
    lambda x: str(x).upper() if str(x).upper() in top_surface else 'OTHER'
)

# Top 6 Light conditions
df['Light'] = df['Light'].replace({
    'DARK - LIGHTED': 'DARK LIGHTS ON',
    'DARK - NOT LIGHTED': 'DARK NO LIGHTS',
})
top_light = df['Light'].str.upper().value_counts().index[:6]
df['Light'] = df['Light'].apply(
    lambda x: str(x).upper() if str(x).upper() in top_light else 'OTHER'
)

# Top 3 traffic controls
top_traffic = df['Traffic Control'].str.upper().value_counts().index[:6]
df['Traffic Control'] = df['Traffic Control'].apply(
    lambda x: str(x).upper() if str(x).upper() in top_traffic else 'OTHER'
)
df['Traffic Control'] = df['Traffic Control'].replace({
    'TRAFFIC CONTROL SIGNAL': 'TRAFFIC SIGNAL',
    'FLASHING TRAFFIC SIGNAL': 'TRAFFIC SIGNAL'
})

# Top 2 substance abuse
df['Driver Substance Abuse'] = df['Driver Substance Abuse'].str.upper().replace({'UNKNOWN': 'OTHER'})
top_substance = df['Driver Substance Abuse'].value_counts().index[:4]
df['Driver Substance Abuse'] = df['Driver Substance Abuse'].apply(
    lambda x: x if x in top_substance else 'OTHER'
)
df['Driver Substance Abuse'] = df['Driver Substance Abuse'].replace({
    'NOT SUSPECT OF ALCOHOL USE, NOT SUSPECT OF DRUG USE': 'NONE DETECTED'
})

# Top 3 distractions
df['Driver Distracted By'] = df['Driver Distracted By'].str.upper().replace({
    'OTHER DISTRACTION': 'OTHER',
    'OTHER ACTION (LOOKING AWAY FROM TASK, ETC.)': 'OTHER',
    'UNKNOWN': 'OTHER'
})
top_distractions = df['Driver Distracted By'].value_counts().index[:4]
df['Driver Distracted By'] = df['Driver Distracted By'].apply(
    lambda x: x if x in top_distractions else 'OTHER'
)

# Top 3 damage types
top_damage = df['Vehicle Damage Extent'].str.upper().value_counts().index[:4]
df['Vehicle Damage Extent'] = df['Vehicle Damage Extent'].apply(
    lambda x: str(x).upper() if str(x).upper() in top_damage else 'OTHER'
)

# Top 5 impact locations
top_times = df['Vehicle First Impact Location'].str.upper().str.replace(" ", "").value_counts().index[:6]
df['Vehicle First Impact Location'] = df['Vehicle First Impact Location'].apply(
    lambda x: str(x).upper().replace(" ", "") if str(x).upper().replace(" ", "") in top_times else 'OTHER'
)

# Top 5 vehicle body types
top_body = df['Vehicle Body Type'].str.upper().value_counts().index[:7]
df['Vehicle Body Type'] = df['Vehicle Body Type'].apply(
    lambda x: str(x).upper() if str(x).upper() in top_body else 'OTHER'
)
df['Vehicle Body Type'] = df['Vehicle Body Type'].replace({
    '(SPORT) UTILITY VEHICLE': 'SPORT UTILITY VEHICLE',
    'TRANSIT BUS': 'BUS',
    'SCHOOL BUS': 'BUS'
})

# Top 5 vehicle movements
top_movement = df['Vehicle Movement'].str.upper().value_counts().index[:5]
df['Vehicle Movement'] = df['Vehicle Movement'].apply(
    lambda x: str(x).upper() if str(x).upper() in top_movement else 'OTHER'
)

# Top 4 car makes
top_make = df['Vehicle Make'].str.upper().value_counts().index[:6]
df['Vehicle Make'] = df['Vehicle Make'].apply(
    lambda x: str(x).upper() if str(x).upper() in top_make else 'OTHER'
)
df['Vehicle Make'] = df['Vehicle Make'].replace({
    'TOYT': 'TOYOTA',
    'HOND': 'HONDA'
})

# Top 6 car models
top_model = df['Vehicle Model'].str.upper().value_counts().index[:6]
df['Vehicle Model'] = df['Vehicle Model'].apply(
    lambda x: str(x).upper() if str(x).upper() in top_model else 'OTHER'
)

# Drop bad car years
df = df[(df['Vehicle Year'] >= 1980) & (df['Vehicle Year'] <= 2025)]

# Label weekday
df['Crash Weekday'] = df['Crash Weekday'].replace({
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
})

# Drop NA rows (Only a few na rows in injury)
df = df.dropna();
# Out:
# /var/folders/7s/y2ptxpt11h7fpjjqb4cphgcc0000gn/T/ipykernel_72480/2718682477.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Crash Weekday'] = df['Crash Weekday'].replace({

# %% [markdown]
# Let us take a look at the columns now!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70786 entries, 0 to 72389
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Collision Type                 70786 non-null  object
#  1   Weather                        70786 non-null  object
#  2   Surface Condition              70786 non-null  object
#  3   Light                          70786 non-null  object
#  4   Traffic Control                70786 non-null  object
#  5   Driver Substance Abuse         70786 non-null  object
#  6   Driver At Fault                70786 non-null  object
#  7   Driver Distracted By           70786 non-null  object
#  8   Vehicle Damage Extent          70786 non-null  object
#  9   Vehicle First Impact Location  70786 non-null  object
#  10  Vehicle Body Type              70786 non-null  object
#  11  Vehicle Movement               70786 non-null  object
#  12  Speed Limit                    70786 non-null  int64
#  13  Vehicle Year                   70786 non-null  int64
#  14  Vehicle Make                   70786 non-null  object
#  15  Vehicle Model                  70786 non-null  object
#  16  Crash Hour                     70786 non-null  int32
#  17  Crash Weekday                  70786 non-null  object
#  18  Injury                         70786 non-null  int64
# dtypes: int32(1), int64(3), object(15)
# memory usage: 10.5+ MB

# %% [markdown]
# We succesfully simplified our predictor variables and did not lose too much data! Now we can start encoding our categorical values.

# %% [markdown]
# ## Extra Credit (Unsupervised Learning)

# %%
features = ['Vehicle Year', 'Crash Hour']
X = df[features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

clf = IsolationForest(contamination=0.03, random_state=42)
outliers = clf.fit_predict(X_scaled)

df['outlier'] = ['Outlier' if o == -1 else 'Inlier' for o in outliers]

sns.scatterplot(
    x='Vehicle Year',
    y='Crash Hour',
    data=df,
    hue='outlier',
    palette=['tab:red', 'tab:blue'],
    s=30
)
plt.title('Anomaly Detection with Isolation Forest')
plt.show();

# %% [markdown]
# Interesting, why are some years, specifically older vehicles, being flagged as outliers? Let's try focusing on newer cars and seeing if that improves our score.

# %%
df_filtered = df[df['Vehicle Year'] >= 1995]
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70121 entries, 0 to 72389
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Collision Type                 70121 non-null  object
#  1   Weather                        70121 non-null  object
#  2   Surface Condition              70121 non-null  object
#  3   Light                          70121 non-null  object
#  4   Traffic Control                70121 non-null  object
#  5   Driver Substance Abuse         70121 non-null  object
#  6   Driver At Fault                70121 non-null  object
#  7   Driver Distracted By           70121 non-null  object
#  8   Vehicle Damage Extent          70121 non-null  object
#  9   Vehicle First Impact Location  70121 non-null  object
#  10  Vehicle Body Type              70121 non-null  object
#  11  Vehicle Movement               70121 non-null  object
#  12  Speed Limit                    70121 non-null  int64
#  13  Vehicle Year                   70121 non-null  int64
#  14  Vehicle Make                   70121 non-null  object
#  15  Vehicle Model                  70121 non-null  object
#  16  Crash Hour                     70121 non-null  int32
#  17  Crash Weekday                  70121 non-null  object
#  18  Injury                         70121 non-null  int64
#  19  outlier                        70121 non-null  object
# dtypes: int32(1), int64(3), object(16)
# memory usage: 11.0+ MB

# %%
df = pd.get_dummies(df, drop_first=True)
df_filtered = pd.get_dummies(df_filtered, drop_first=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70786 entries, 0 to 72389
# Data columns (total 72 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Speed Limit                                  70786 non-null  int64
#  1   Vehicle Year                                 70786 non-null  int64
#  2   Crash Hour                                   70786 non-null  int32
#  3   Injury                                       70786 non-null  int64
#  4   Collision Type_OTHER                         70786 non-null  bool
#  5   Collision Type_SAME DIR REAR END             70786 non-null  bool
#  6   Collision Type_SAME DIRECTION SIDESWIPE      70786 non-null  bool
#  7   Collision Type_SINGLE VEHICLE                70786 non-null  bool
#  8   Collision Type_STRAIGHT MOVEMENT ANGLE       70786 non-null  bool
#  9   Weather_CLOUDY                               70786 non-null  bool
#  10  Weather_OTHER                                70786 non-null  bool
#  11  Weather_RAIN                                 70786 non-null  bool
#  12  Weather_SNOW                                 70786 non-null  bool
#  13  Surface Condition_ICE                        70786 non-null  bool
#  14  Surface Condition_OTHER                      70786 non-null  bool
#  15  Surface Condition_SNOW                       70786 non-null  bool
#  16  Surface Condition_WET                        70786 non-null  bool
#  17  Light_DARK LIGHTS ON                         70786 non-null  bool
#  18  Light_DARK NO LIGHTS                         70786 non-null  bool
#  19  Light_DAWN                                   70786 non-null  bool
#  20  Light_DAYLIGHT                               70786 non-null  bool
#  21  Light_DUSK                                   70786 non-null  bool
#  22  Light_OTHER                                  70786 non-null  bool
#  23  Traffic Control_OTHER                        70786 non-null  bool
#  24  Traffic Control_STOP SIGN                    70786 non-null  bool
#  25  Traffic Control_TRAFFIC SIGNAL               70786 non-null  bool
#  26  Traffic Control_YIELD SIGN                   70786 non-null  bool
#  27  Driver Substance Abuse_OTHER                 70786 non-null  bool
#  28  Driver Substance Abuse_UNKNOWN, UNKNOWN      70786 non-null  bool
#  29  Driver At Fault_Unknown                      70786 non-null  bool
#  30  Driver At Fault_Yes                          70786 non-null  bool
#  31  Driver Distracted By_LOOKED BUT DID NOT SEE  70786 non-null  bool
#  32  Driver Distracted By_NOT DISTRACTED          70786 non-null  bool
#  33  Driver Distracted By_OTHER                   70786 non-null  bool
#  34  Vehicle Damage Extent_DISABLING              70786 non-null  bool
#  35  Vehicle Damage Extent_FUNCTIONAL             70786 non-null  bool
#  36  Vehicle Damage Extent_OTHER                  70786 non-null  bool
#  37  Vehicle Damage Extent_SUPERFICIAL            70786 non-null  bool
#  38  Vehicle First Impact Location_ONEOCLOCK      70786 non-null  bool
#  39  Vehicle First Impact Location_OTHER          70786 non-null  bool
#  40  Vehicle First Impact Location_SIXOCLOCK      70786 non-null  bool
#  41  Vehicle First Impact Location_TENOCLOCK      70786 non-null  bool
#  42  Vehicle First Impact Location_TWELVEOCLOCK   70786 non-null  bool
#  43  Vehicle First Impact Location_TWOOCLOCK      70786 non-null  bool
#  44  Vehicle Body Type_MOTORCYCLE                 70786 non-null  bool
#  45  Vehicle Body Type_OTHER                      70786 non-null  bool
#  46  Vehicle Body Type_PASSENGER CAR              70786 non-null  bool
#  47  Vehicle Body Type_PICKUP TRUCK               70786 non-null  bool
#  48  Vehicle Body Type_SPORT UTILITY VEHICLE      70786 non-null  bool
#  49  Vehicle Body Type_VAN                        70786 non-null  bool
#  50  Vehicle Movement_MAKING LEFT TURN            70786 non-null  bool
#  51  Vehicle Movement_MOVING CONSTANT SPEED       70786 non-null  bool
#  52  Vehicle Movement_OTHER                       70786 non-null  bool
#  53  Vehicle Movement_SLOWING OR STOPPING         70786 non-null  bool
#  54  Vehicle Movement_STOPPED IN TRAFFIC LANE     70786 non-null  bool
#  55  Vehicle Make_HONDA                           70786 non-null  bool
#  56  Vehicle Make_NISSAN                          70786 non-null  bool
#  57  Vehicle Make_OTHER                           70786 non-null  bool
#  58  Vehicle Make_TOYOTA                          70786 non-null  bool
#  59  Vehicle Model_ACCORD                         70786 non-null  bool
#  60  Vehicle Model_CAMRY                          70786 non-null  bool
#  61  Vehicle Model_CIVIC                          70786 non-null  bool
#  62  Vehicle Model_COROLLA                        70786 non-null  bool
#  63  Vehicle Model_OTHER                          70786 non-null  bool
#  64  Vehicle Model_TK                             70786 non-null  bool
#  65  Crash Weekday_Monday                         70786 non-null  bool
#  66  Crash Weekday_Saturday                       70786 non-null  bool
#  67  Crash Weekday_Sunday                         70786 non-null  bool
#  68  Crash Weekday_Thursday                       70786 non-null  bool
#  69  Crash Weekday_Tuesday                        70786 non-null  bool
#  70  Crash Weekday_Wednesday                      70786 non-null  bool
#  71  outlier_Outlier                              70786 non-null  bool
# dtypes: bool(68), int32(1), int64(3)
# memory usage: 7.0 MB

# %%
df.sample(5)
# Out:
#        Speed Limit  Vehicle Year  Crash Hour  Injury  Collision Type_OTHER  \
# 39735           40          1996           7       0                 False
# 49731           35          2010          19       0                  True
# 720             25          2019          15       0                 False
# 65206           40          2004          13       1                 False
# 59954           40          2005          18       1                 False
#
#        Collision Type_SAME DIR REAR END  \
# 39735                              True
# 49731                             False
# 720                                True
# 65206                              True
# 59954                              True
#
#        Collision Type_SAME DIRECTION SIDESWIPE  Collision Type_SINGLE VEHICLE  \
# 39735                                    False                          False
# 49731                                    False                          False
# 720                                      False                          False
# 65206                                    False                          False
# 59954                                    False                          False
#
#        Collision Type_STRAIGHT MOVEMENT ANGLE  Weather_CLOUDY  ...  \
# 39735                                   False           False  ...
# 49731                                   False           False  ...
# 720                                     False           False  ...
# 65206                                   False           False  ...
# 59954                                   False           False  ...
#
#        Vehicle Model_COROLLA  Vehicle Model_OTHER  Vehicle Model_TK  \
# 39735                  False                False             False
# 49731                  False                 True             False
# 720                    False                 True             False
# 65206                  False                 True             False
# 59954                  False                 True             False
#
#        Crash Weekday_Monday  Crash Weekday_Saturday  Crash Weekday_Sunday  \
# 39735                 False                   False                 False
# 49731                 False                   False                  True
# 720                    True                   False                 False
# 65206                 False                   False                 False
# 59954                 False                    True                 False
#
#        Crash Weekday_Thursday  Crash Weekday_Tuesday  Crash Weekday_Wednesday  \
# 39735                   False                  False                    False
# 49731                   False                  False                    False
# 720                     False                  False                    False
# 65206                    True                  False                    False
# 59954                   False                  False                    False
#
#        outlier_Outlier
# 39735             True
# 49731            False
# 720              False
# 65206            False
# 59954            False
#
# [5 rows x 72 columns]

# %% [markdown]
# Great now we can start the preperation for machine learning!

# %% [markdown]
# # Machine learning

# %% [markdown]
# ## Data preparation for machine learning

# %% [markdown]
# ### Convert Pandas data to NumPy

# %%
target = 'Injury'
predictors = df.columns[~df.columns.isin(['Injury'])]

# %%
X = df[predictors].values
y = df[target].values

# %% [markdown]
# ### Train/test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
print('The training set has {} rows, with {} predictor variables.'.format(X_train.shape[0], X_train.shape[1]))
# Out:
# The training set has 56628 rows, with 71 predictor variables.

# %% [markdown]
# ### Scale the data

# %%
quant_features = [0,1,2]
xform = ColumnTransformer(
    transformers=[
        ('scaler', StandardScaler(), quant_features)
    ],
    remainder='passthrough'
)

X_train = xform.fit_transform(X_train)
X_test  = xform.transform(X_test)

print(X_train.shape)
# Out:
# (56628, 71)

# %% [markdown]
# Based on our rows and predictor values from our train/split and our scaled size, the size was not changed and by viewing the indexes, we can see the scaled values.

# %% [markdown]
# ### Compute baseline accuracy

# %%
majority_class = pd.Series(y_train).value_counts().index[0]
baseline_accuracy = (majority_class == y_train).mean()
print(f"Baseline accuracy: {baseline_accuracy:.3f}")
# Out:
# Baseline accuracy: 0.504

# %%
# Print shapes to check
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)

# Trim y_train to match X_train's length
y_train = y_train[:56096]

# Trim y_test to match X_test's length
y_test = y_test[:14025]

# Convert to proper numeric types
X_train = X_train.astype(float)
X_test = X_test.astype(float)

# Now fit the model
clf = DecisionTreeClassifier(max_depth=10, random_state=0)
clf.fit(X_train, y_train)

# Get feature importance
feature_importance = pd.DataFrame({
    'feature': [f'Feature_{i}' for i in range(X_train.shape[1])],  # Create generic feature names
    'importance': clf.feature_importances_
})
feature_importance = feature_importance.sort_values('importance', ascending=False)
print("\nFeature Importance:")
print(feature_importance)

# Visualize feature importance
plt.figure(figsize=(10, 6))
plt.bar(feature_importance['feature'], feature_importance['importance'])
plt.xticks(rotation=45, ha='right')
plt.title('Feature Importance')
plt.tight_layout()
plt.show()

# Calculate test accuracy
test_accuracy = clf.score(X_test, y_test)
print(f"\nTest accuracy: {test_accuracy:.3f}")
# Out:
# X_test shape: (14158, 71)
# y_test shape: (14158,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 17
#      15 # Now fit the model
#      16 clf = DecisionTreeClassifier(max_depth=10, random_state=0)
# ---> 17 clf.fit(X_train, y_train)
#      19 # Get feature importance
#      20 feature_importance = pd.DataFrame({
#      21     'feature': [f'Feature_{i}' for i in range(X_train.shape[1])],  # Create generic feature names
#      22     'importance': clf.feature_importances_
#      23 })
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/tree/_classes.py:1009, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     978 @_fit_context(prefer_skip_nested_validation=True)
#     979 def fit(self, X, y, sample_weight=None, check_input=True):
#     980     """Build a decision tree classifier from the training set (X, y).
#     981
#     982     Parameters
#    (...)
#    1006         Fitted estimator.
#    1007     """
# -> 1009     super()._fit(
#    1010         X,
#    1011         y,
#    1012         sample_weight=sample_weight,
#    1013         check_input=check_input,
#    1014     )
#    1015     return self
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/tree/_classes.py:355, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     352 max_leaf_nodes = -1 if self.max_leaf_nodes is None else self.max_leaf_nodes
#     354 if len(y) != n_samples:
# --> 355     raise ValueError(
#     356         "Number of labels=%d does not match number of samples=%d"
#     357         % (len(y), n_samples)
#     358     )
#     360 if sample_weight is not None:
#     361     sample_weight = _check_sample_weight(sample_weight, X, DOUBLE)
#
# ValueError: Number of labels=56096 does not match number of samples=56628

# %% [markdown]
# To outperform the baseline accuracy of 0.502, our model must achieve an accuracy rate greater than 0.502.

# %%
def plot_learning_curve(clf, X_train, y_train):
    train_sizes, train_scores, test_scores = \
    learning_curve(clf, X_train, y_train, cv=5, scoring='accuracy')
    train_scores_mean = np.mean(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    plt.plot(train_sizes, train_scores_mean, label='train')
    plt.plot(train_sizes, test_scores_mean, label='test')
    plt.xlabel('Training Set Size')
    plt.ylabel('Accuracy')
    plt.title('Learning curve')
    plt.legend();

# %% [markdown]
# Before Starting with Machine learning algorthms we want to reduce the feature a little but as 68 feature will cause alot of time and cofunse our model

# %% [markdown]
# ## Mutual Information Visualize first

# %%
selector = SelectKBest(mutual_info_classif, k=8)
selector.fit(X_train, y_train)

feature_scores = pd.Series(selector.scores_, index=predictors)

feature_scores.nlargest(8).sort_values().plot.barh()
plt.title("Top 8 Mutual-Information Scores")
plt.show()

# %% [markdown]
# ## Select best 5 features

# %%
X_train_best = selector.transform(X_train)
X_test_best  = selector.transform(X_test)
chosen = [col for col, keep in zip(predictors, selector.get_support()) if keep]
print("Selected features:", chosen)

# %% [markdown]
# ## Logistic regression

# %%
reg = LogisticRegression();
reg.fit(X_train_best, y_train);
print("Test accuracy:", reg.score(X_test_best, y_test));

# %% [markdown]
# We see that our accuracy acually become lower than before, maybe logistic regression not the right alogorthms to predict the target for this data set.

# %% [markdown]
# ### Compare filtered df and original df

# %%
X_fil = df_filtered[predictors].values
y_fil = df_filtered[target].values

X_train, X_test, y_train, y_test = train_test_split(X_fil, y_fil, test_size=0.20, random_state=42)

quant_features = [0, 1, 2]
xform = ColumnTransformer(
    transformers=[
        ('scaler', StandardScaler(), quant_features)
    ],
    remainder='passthrough'
)

X_train_trans = xform.fit_transform(X_train)
X_test_trans = xform.transform(X_test)

filt_reg = LogisticRegression()
filt_reg.fit(X_train_trans, y_train)

print("Test accuracy:", filt_reg.score(X_test_trans, y_test))

# %% [markdown]
# Our filtered df is performing better, so lets keep it!

# %% [markdown]
# now lets plot our learning curve to see how our train and test data performing

# %%
plot_learning_curve(filt_reg, X_train_trans, y_train)

# %%
scores = cross_val_score(
    estimator=filt_reg,
    X=X_train_trans,
    y=y_train,
    scoring='accuracy',
    cv=5
)

print("All 5-fold CV accuracy scores:", scores)
print("Mean 5-fold accuracy:         ", round(scores.mean(), 4))

# %% [markdown]
# ## Classification Tree

# %%
# First fix the size mismatch
X_train_best = X_train_best[:56096]  # Trim to match y_train's length

# Convert to proper numeric types
X_train_best = X_train_best.astype(float)

# Now fit the model
clf = DecisionTreeClassifier(max_depth=10, random_state=0)
clf.fit(X_train_best, y_train)


clf = DecisionTreeClassifier(max_depth=10, random_state=0)
clf.fit(X_train_best, y_train);

# %%
def plot_tree_custom(clf, feature_names, class_names):
    dot_data = export_graphviz(clf, precision=2,
                         feature_names=feature_names,
                         proportion=True,
                         class_names=class_names,
                         filled=True, rounded=True,
                         special_characters=True)

    graph = graphviz.Source(dot_data)
    return graph

# %%
def plot_tree_custom_basic(clf, feature_names, class_names, max_depth=3):
    fig, ax = plt.subplots(figsize=(20, 10), dpi=150)
    plot_tree(
        clf,
        feature_names=feature_names,
        class_names=class_names,
        filled=True,
        rounded=True,
        proportion=True,
        fontsize=10,
        max_depth=max_depth,
        ax=ax,
    )
    plt.show()

# %%
plot_learning_curve(clf, X_train_best, y_train)

# %% [markdown]
# We can observe the our model is bias and here we need to change our paramertes values to remove this overfitting

# %% [markdown]
# # Hyperparameter tuning

# %% [markdown]
# we would like to adjust the parameters for our model ("min_samples_leaf" and "max_depth" to get better accuarcy

# %%
grid = {'max_depth': range(2,10,1),
               'min_samples_leaf':[10, 15, 20, 25, 30],
               'max_features': ['sqrt', None]}
tree_cv = GridSearchCV(clf, grid, cv=10)
tree_cv.fit(X_train_best, y_train);

# %%
print(tree_cv.best_params_)

# %%
best_accuracy = tree_cv.best_score_
print(f"Best cross-validation accuracy: {best_accuracy:.3f}")

# %%
plot_learning_curve(tree_cv.best_estimator_, X_train_best, y_train)

# %%
best_tree = tree_cv.best_estimator_
plot_tree_custom_basic(best_tree,feature_names=chosen,class_names=['No Injury','Injury'],max_depth=3)

# %%
dot_data = export_graphviz(
    clf,
    out_file=None,
    feature_names=chosen,
    class_names=['No Injury','Injury'],
    filled=True,
    rounded=True,
    special_characters=True)
graph = graphviz.Source(dot_data)
graph

# %%
# # Check the shapes of test data
# print("X_test_best shape:", X_test_best.shape)
# print("y_test shape:", y_test.shape)

# # Check data types
# print("\nX_test_best type:", type(X_test_best))
# print("y_test type:", type(y_test))

# # Check first few rows
# print("\nX_test_best head:")
# print(X_test_best[:5])
# print("\ny_test head:")
# print(y_test[:5])
# First fix the size mismatch
X_test_best = X_test_best[:14025]  # Trim to match y_test's length

# Convert to proper numeric types
X_test_best = X_test_best.astype(float)

# Now calculate the test accuracy
test_accuracy = tree_cv.score(X_test_best, y_test)
print(f"Test accuracy: {test_accuracy:.3f}")
test_accuracy = tree_cv.score(X_test_best, y_test)
print(f"Test accuracy: {test_accuracy:.3f}")

# %%
from sklearn.ensemble import RandomForestClassifier

# Train Random Forest with some initial parameters
rf_clf = RandomForestClassifier(
    n_estimators=100,  # number of trees
    max_depth=10,      # maximum depth of trees
    min_samples_split=5,  # minimum samples required to split a node
    min_samples_leaf=2,   # minimum samples required in a leaf node
    random_state=0
)

# Fit the model
rf_clf.fit(X_train, y_train)

# Calculate test accuracy
rf_accuracy = rf_clf.score(X_test, y_test)
print(f"\nRandom Forest test accuracy: {rf_accuracy:.3f}")

# Get feature importance from Random Forest
rf_feature_importance = pd.DataFrame({
    'feature': [f'Feature_{i}' for i in range(X_train.shape[1])],
    'importance': rf_clf.feature_importances_
})
rf_feature_importance = rf_feature_importance.sort_values('importance', ascending=False)
print("\nTop 10 Most Important Features:")
print(rf_feature_importance.head(10))

# Visualize feature importance
plt.figure(figsize=(10, 6))
plt.bar(rf_feature_importance['feature'], rf_feature_importance['importance'])
plt.xticks(rotation=45, ha='right')
plt.title('Random Forest Feature Importance')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We set out to predict if a car accident results in injury in Maryland vehicle crashes using machine learning. After exploring the dataset and doing some data cleaning, we trained a logistic regression model using a mix of crash related features such as collision type, vehicle damage extent, surface and weather conditions, lighting, time of crash, and more. To give ourselves a baseline for comparison, we looked at how well we'd do by just predicting the most common outcome every time (which was "No Injury"). That gave us a baseline accuracy of about 81.4%. Our model performed slightly better, around 82%. We also ran an experiment by filtering out crashes involving older vehicles (pre-1995), this gave us a small bump in accuracy. Our data visualizations backed up some expectations. Most crashes in the dataset didn’t involve any injury at all, so the dataset was highly imbalanced toward the "no injury" class. This imbalance probably made it harder for the model to learn meaningful patterns about injuries. We also noticed that certain conditions such as poor lighting, rain, or icy roads occurred far less frequently. Even though we beat the baseline, cross validation results showed a slight dip in accuracy when evaluating performance across different data splits. That could suggests that some of our predictors might not generalize well and could be adding noise. The logistic regression model gave us a solid starting point, but it might not be the best for this imbalanced classification problem.
